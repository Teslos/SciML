# %% [markdown]
# # Problem
# The new test for solving pde using pytorch:
#
# $
# \frac{\partial{u}}{\partial t} = \frac{\partial^2 u}{\partial{x}^2}+\frac{\partial^2 u}{\partial{y}^2} +f
# $
#
# in the square region $0 \le x \le 1$ and $ 0 \le y \le 1$
#
# with initial conditions: $u(x,y,0)=0$
#
# and boundary condition: $u(0,y,t) = 0, u(1,y,t) = 0, u(x,0,t) = 0, u(x,1,t) = 0$
# for the time $0 \le t \le 4$
#
# Independent variables:
# * t - time
# * x - coordinate
# * y - coordinate
#
# Dependent variables output:
# * u - diffusion species

# %%
import torch
import torch.backends
import torch.nn as nn
from collections import OrderedDict
from torch.autograd import Variable
from torch.utils.data import Dataset, DataLoader
import numpy as np
import os

device = "cpu"
if torch.cuda.is_available():
    device = "cuda"
elif hasattr(torch.backends, 'mps') and torch.backends.mps.is_available():
    device = "mps"
print("using device: ", device)
# Out:
# using device:  cuda

# %%
# rewrite in layer, this is rather boilplate code 
class DiffNet(nn.Module):
    def __init__(self, input_size,hidden_size,
                output_size, depth, act=torch.nn.Tanh):
        super(DiffNet, self).__init__()
         # hyperparameters
        self.lambda_residual = 1.0
        self.kernel_regularizer = 0.0 
        self.regularization_param = 0.0
      

        layers = [('input', torch.nn.Linear(input_size, hidden_size))]
        layers.append(('input_activation', act()))
        for i in range(depth):
            layers.append(
                ('hidden_%d' %i, torch.nn.Linear(hidden_size, hidden_size))
            )
            layers.append(('activation_%d' %i,act()))
        layers.append(('output', torch.nn.Linear(hidden_size, output_size)))
        
        layerDict = OrderedDict(layers)
        self.layers = torch.nn.Sequential(layerDict)
    
    def forward(self, X):
        inputs = X 
        out = self.layers(inputs)
        return out

# %% [markdown]
# "Complex" is the NN proposed by Giulio to solve heat and diffusion problem. I added the possibility of having different activation function which can be choosen using the string name. In most of the literature it is suggested to have at least
# two time differentiable function like "sin" and "tanh" for solving the PDE using PINNs.

# %%
class Swish(nn.Module):
    def __init__(self, ):
        super().__init__()

    def forward(self, x):
        return x * torch.sigmoid(x)


class Sin(nn.Module):
    def __init__(self, ):
        super().__init__()

    def forward(self, x):
        return torch.sin(x)
    
def activation(name):
    if name in ['tanh', 'Tanh']:
        return nn.Tanh()
    elif name in ['relu', 'ReLU']:
        return nn.ReLU(inplace=True)
    elif name in ['lrelu', 'LReLU']:
        return nn.LeakyReLU(inplace=True)
    elif name in ['sigmoid', 'Sigmoid']:
        return nn.Sigmoid()
    elif name in ['softplus', 'Softplus']:
        return nn.Softplus(beta=4)
    elif name in ['celu', 'CeLU']:
        return nn.CELU()
    elif name in ['swish']:
        return Swish()
    elif name in ['sin']:
        return Sin()
    elif name in ['gelu']:
        return nn.GELU()
    else:
        raise ValueError('Unknown activation function')
    
class ComplexHeatEquationNet(torch.nn.Module):
    def __init__(self):
        super(ComplexHeatEquationNet, self).__init__()
        # hyperparameters
        self.lambda_residual = 1.0
        self.kernel_regularizer = 0.0 
        self.regularization_param = 0.0
        self.act_string = "sin"
        self.activation = activation(self.act_string) 
        self.fc1 = torch.nn.Linear(3, 512)
        self.ln1 = torch.nn.LayerNorm(512)
        self.fc2 = torch.nn.Linear(512, 256)
        self.ln2 = torch.nn.LayerNorm(256)
        self.fc3 = torch.nn.Linear(256, 128)
        self.ln3 = torch.nn.LayerNorm(128)
        self.fc4 = torch.nn.Linear(128, 64)
        self.ln4 = torch.nn.LayerNorm(64)
        self.fc5 = torch.nn.Linear(64, 32)
        self.ln5 = torch.nn.LayerNorm(32)
        self.fc6 = torch.nn.Linear(32, 1)

    def forward(self, X):
        x = self.activation(self.ln1(self.fc1(X)))
        x = self.activation(self.ln2(self.fc2(x)))
        x = self.activation(self.ln3(self.fc3(x)))
        x = self.activation(self.ln4(self.fc4(x)))
        x = self.activation(self.ln5(self.fc5(x)))
        x = self.fc6(x)
        return x

# %%
class SineLayer(torch.nn.Module):
    # See paper sec. 3.2, final paragraph, and supplement Sec. 1.5 for discussion of omega_0.
    
    # If is_first=True, omega_0 is a frequency factor which simply multiplies the activations before the 
    # nonlinearity. Different signals may require different omega_0 in the first layer - this is a 
    # hyperparameter.
    
    # If is_first=False, then the weights will be divided by omega_0 so as to keep the magnitude of 
    # activations constant, but boost gradients to the weight matrix (see supplement Sec. 1.5)
    
    def __init__(self, in_features, out_features, bias=True,
                 is_first=False, omega_0=30):
        super().__init__()
        self.omega_0 = omega_0
        self.is_first = is_first
        
        self.in_features = in_features
        self.linear = nn.Linear(in_features, out_features, bias=bias)
        
        self.init_weights()
    
    def init_weights(self):
        with torch.no_grad():
            if self.is_first:
                self.linear.weight.uniform_(-1 / self.in_features, 
                                             1 / self.in_features)      
            else:
                self.linear.weight.uniform_(-np.sqrt(6 / self.in_features) / self.omega_0, 
                                             np.sqrt(6 / self.in_features) / self.omega_0)
        
    def forward(self, input):
        return torch.sin(self.omega_0 * self.linear(input))
    
    def forward_with_intermediate(self, input): 
        # For visualization of activation distributions
        intermediate = self.omega_0 * self.linear(input)
        return torch.sin(intermediate), intermediate
    
    
class Siren(torch.nn.Module):
    def __init__(self, in_features, hidden_features, hidden_layers, out_features, outermost_linear=False, 
                 first_omega_0=30, hidden_omega_0=30.):
        super().__init__()
        
        self.net = []
        self.net.append(SineLayer(in_features, hidden_features, 
                                  is_first=True, omega_0=first_omega_0))

        for i in range(hidden_layers):
            self.net.append(SineLayer(hidden_features, hidden_features, 
                                      is_first=False, omega_0=hidden_omega_0))

        if outermost_linear:
            final_linear = nn.Linear(hidden_features, out_features)
            
            with torch.no_grad():
                final_linear.weight.uniform_(-np.sqrt(6 / hidden_features) / hidden_omega_0, 
                                              np.sqrt(6 / hidden_features) / hidden_omega_0)
                
            self.net.append(final_linear)
        else:
            self.net.append(SineLayer(hidden_features, out_features, 
                                      is_first=False, omega_0=hidden_omega_0))
        
        self.net = nn.Sequential(*self.net)
    
    def forward(self, coords):
        output = self.net(coords)
        return output       

    def forward_with_activations(self, coords, retain_grad=False):
        '''Returns not only model output, but also intermediate activations.
        Only used for visualizing activations later!'''
        activations = OrderedDict()

        activation_count = 0
        x = coords.clone().detach().requires_grad_(True)
        activations['input'] = x
        for i, layer in enumerate(self.net):
            if isinstance(layer, SineLayer):
                x, intermed = layer.forward_with_intermediate(x)
                
                if retain_grad:
                    x.retain_grad()
                    intermed.retain_grad()
                    
                activations['_'.join((str(layer.__class__), "%d" % activation_count))] = intermed
                activation_count += 1
            else: 
                x = layer(x)
                
                if retain_grad:
                    x.retain_grad()
                    
            activations['_'.join((str(layer.__class__), "%d" % activation_count))] = x
            activation_count += 1

        return activations

# %% [markdown]
# Differential model for this equation is very similar as for one-dimensional case.
# * predict out based on the coordinates $x, y$ and time $t$.

# %%
import SquareDomain as sd
class DirichletBC:
    def __init__(self):
        pass

    def apply(self, model, x_boundary, u_boundary, n_out, u_pred_var_list, u_train_var_list, space_dim = None, x_boundary_sym=None, boundary=None, vel_wave=None):
        u_boundary_pred = model(x_boundary)
        u_pred_var_list.append(u_boundary_pred[:, n_out])
        u_train_var_list.append(u_boundary[:, n_out])
        return boundary

# %%
import SquareDomain as sd
from GeneratorPoints import generator_points


class DiffClass(nn.Module):
    def __init__ (self, pretrain=False):
        super().__init__()
        self.random_seed = 423
        torch.manual_seed(self.random_seed)
        self.output_dimensions = 1
        self.time_dimensions = 1
        self.space_dimensions = 2
        self.parameter_dimensions = 0
        self.extrema_values = torch.tensor([[0,4],[0,1],[0,1]])
        self.boundary_points = 4
        self.list_of_bc = list([[self.ub0, self.ub0], [self.ub0, self.ub0]])
        self.pretrain = pretrain
        self.square_domain = sd.SquareDomain(self.output_dimensions,
                                             self.time_dimensions,
                                             self.space_dimensions,
                                             self.list_of_bc,
                                             self.extrema_values, "sobol")
        self.Nsamples = 1000 
        self.counter = 0
        self.full_count = 10000

    
    def f(self,coords):
        if coords.shape[1] == 3:
            t = coords[:,0]
            x = coords[:,1]
            y = coords[:,2]
        return 10 * torch.sin(np.pi * x)**10 * torch.sin(np.pi * y)**10 * torch.sin(np.pi * t)**10
    
    def ub0(self, t):
        type_BC = [DirichletBC()]
        u = torch.zeros(t.shape[0])
        u = u.reshape(-1,1)
        return u, type_BC   

    def u0(self, t):
        ''' Adds Dirichlet boundary conditions sets the temperature'''
        self.ini = 0
        u = torch.ones(t.shape[0]) * self.ini
        #u = self.true_sol_func(t)
        return u

    def add_collocation_points(self, n_coll, random_seed=None):
        # uniformly sample domain and include coordinates
        x_coll, y_coll = self.square_domain.add_collocation_points(n_coll, self.random_seed)
        print(x_coll.shape)
        return x_coll, y_coll
    
    def add_boundary_points(self, n_boundary, random_seed=None):
        # boundary values and coordinates
        boundary, boundary_values = self.square_domain.add_boundary_points(n_boundary, self.random_seed)
        boundary_values = boundary_values.unsqueeze(-1)
        print(f"boundary_values: {boundary_values.shape}")
        return boundary, boundary_values
    
    def apply_bc(self, model, x_b_train, u_b_train, u_pred_var_list, u_train_var_list):
        self.square_domain.apply_boundary_conditions(model, x_b_train, u_b_train, u_pred_var_list, u_train_var_list)
         
    def apply_ic(self, model, x_u_train, u_train, u_pred_var_list, u_train_var_list):
        for j in range(self.output_dimensions):
            if x_u_train.shape[0] != 0:
                u = model(x_u_train)[:,j]
                u_pred_var_list.append(u)
                u_train_var_list.append(u_train[:])
                L2 = torch.mean((u - u_train[:])**2) / torch.mean((u_train[:])**2)
                max = torch.max(u - u_train[:])
                #print("L2 error: ", L2.item())
                #print("max error: ", max.item())

    def add_initial_points(self, n_initial, random_seed=None):
        extrema_0 = self.extrema_values[:,0] # lower bound
        extrema_f = self.extrema_values[:,1] # upper bound
        # create n number of initial points in the domain of the PDE and parameter space
        x_time_0 = generator_points(n_initial, self.time_dimensions + self.space_dimensions + self.parameter_dimensions, random_seed, "sobol", 0.1) 
        x_time_0[:,0] = torch.full(size=(n_initial,), fill_value=0.0) # initial time is 0
        # rest of the points in the domain are scaled to the size of domain
        x_time_0 = x_time_0 * (extrema_f - extrema_0) + extrema_0
        y_time_0 = self.u0(x_time_0)
        print(y_time_0.shape)
        return x_time_0, y_time_0

    def compute_residual(self, net, x_f_train ):
        self.network = net
        x_f_train.requires_grad = True
        u = self.network(x_f_train)[:,0].reshape(-1) 
        # compute gradient of u wrt x
        grad_u = torch.autograd.grad(u, x_f_train, grad_outputs=torch.ones(u.shape).to(device), create_graph=True)[0] 
        grad_u_t = grad_u[:,0]
        grad_u_x = grad_u[:,1]
        grad_u_y = grad_u[:,2]
        # compute second order derivatives
        grad_u_xx = torch.autograd.grad(grad_u_x, x_f_train, grad_outputs=torch.ones(grad_u_x.shape).to(device), create_graph=True)[0][:,1]
        grad_u_yy = torch.autograd.grad(grad_u_y, x_f_train, grad_outputs=torch.ones(grad_u_y.shape).to(device), create_graph=True)[0][:,2]
        # compute residual
        residual = grad_u_xx.reshape(-1,) + grad_u_yy.reshape(-1,) + self.f(x_f_train).reshape(-1,)
        residual = grad_u_t.reshape(-1,) - residual
        return residual

# %%
class DefineDataset:
    def __init__(self, diff, n_collocation, n_boundary, n_initial, n_internal, batches, random_seed, shuffle=False):
        self.n_collocation = n_collocation
        self.n_boundary = n_boundary
        self.n_initial = n_initial
        self.n_internal = n_internal
        self.batches = batches
        self.random_seed = random_seed
        self.shuffle = shuffle
        self.diff = diff
        
        self.space_dimensions = diff.space_dimensions
        self.output_dimensions = diff.output_dimensions
        self.time_dimensions = diff.time_dimensions
        self.input_dimensions = self.space_dimensions + self.time_dimensions

        self.n_samples = n_collocation + 2 * n_boundary * self.space_dimensions + n_initial * self.time_dimensions + n_internal
        self.BC = None
        self.data_coll = None
        self.data_boundary = None
        self.data_initial_internal = None

        if self.batches == "full":
            self.batches = int(self.n_samples)
        else:
            self.batches = int(batches)
        
    def assemble_dataset(self, safe=True):

        fraction_coll = int(self.batches * self.n_collocation / self.n_samples)
        fraction_boundary = int(self.batches * 2* self.n_boundary * self.space_dimensions / self.n_samples)
        fraction_initial = int(self.batches * self.n_initial / self.n_samples)
        fraction_internal = int(self.batches * self.n_internal / self.n_samples)

        x_coll, y_coll = self.diff.add_collocation_points(self.n_collocation, self.random_seed)
        x_b, y_b = self.diff.add_boundary_points(self.n_boundary, self.random_seed)
        print(f"boundary shapes: {x_b.shape}, {y_b.shape}")
        
        # test if the boundary points are correct
        #y_b, _ = self.diff.ub0(x_b)
        #assert torch.equal(y_b,u_b[0])
        

        x_time_internal, y_time_internal = self.diff.add_initial_points(self.n_initial, self.random_seed)
        
        print (x_time_internal.shape)
        print(y_time_internal.shape)

        """ if self.n_internal != 0:
            x_internal, y_internal = self.diff.add_internal_points(self.n_internal, self.random_seed)
            print (x_internal.shape, y_internal.shape)
            x_time_internal = torch.cat((x_time_internal, x_internal), 0)
            y_time_internal = torch.cat((y_time_internal, y_internal), 0)
         """
        print("##############################################")
        print("collocation: ", x_coll[1:10,:], x_coll.shape, y_coll.shape)
        print(' collocation_max: ', torch.max(x_coll, 0)[0], '\n', 'collocation_min: ', torch.min(x_coll, 0)[0])
        #print('internal:', x_time_internal[1:10,:], x_time_internal.shape, y_time_internal.shape)

        if self.n_collocation == 0:
            self.data_coll = DataLoader(torch.utils.data.TensorDataset(x_coll, y_coll), batch_size = 1, shuffle = False)
        else:
            self.data_coll = DataLoader(torch.utils.data.TensorDataset(x_coll, y_coll), batch_size = fraction_coll, shuffle = self.shuffle)

        if self.n_boundary == 0:
            self.data_boundary = DataLoader(torch.utils.data.TensorDataset(x_b, y_b), batch_size = 1, shuffle = False)
        else:
            self.data_boundary = DataLoader(torch.utils.data.TensorDataset(x_b, y_b), batch_size = fraction_boundary, shuffle = self.shuffle)

        if fraction_internal == 0 and fraction_initial == 0:
            self.data_initial_internal = DataLoader(torch.utils.data.TensorDataset(x_time_internal, y_time_internal), batch_size = 1, shuffle = False)
        else:
            self.data_initial_internal = DataLoader(torch.utils.data.TensorDataset(x_time_internal, y_time_internal), batch_size = fraction_initial + fraction_internal, 
                                                    shuffle = self.shuffle)
            
        if safe:
            folder = "Points"
            if (not os.path.exists(folder)):
                os.makedirs(folder)

            torch.save(x_coll, f"{folder}/x_coll_{folder}.pt")
            torch.save(y_coll, f"{folder}/y_coll_{folder}.pt")
            torch.save(x_b, f"{folder}/x_b_{folder}.pt")
            torch.save(y_b, f"{folder}/y_b_{folder}.pt")

            torch.save(x_time_internal, f"{folder}/x_time_internal_{folder}.pt")
            torch.save(y_time_internal, f"{folder}/y_time_internal_{folder}.pt")
            print("Saved points dataset")

# %% [markdown]
# Main class of the NN to solve the heat diffusion. Learning rate choosen is "rather" big 0.01 and can be reduced 10x

# %% [markdown]
# This defines the custom loss for the NN. We have also regularization of the network using `regularization` function

# %%
class CustomLoss(torch.nn.Module):
    def __init__(self):
        super(CustomLoss, self).__init__()
        

    def forward(self,  diff, net,  x_u_train, u_train, x_b_train, u_b_train, x_f_train, dataclass):
        # fetch some hyperparameters
        lambda_residual = net.lambda_residual
        lambda_reg = net.regularization_param
        order_regularizer = net.kernel_regularizer
        M = torch.triu(torch.ones(x_f_train.shape[0], x_f_train.shape[0]), diagonal=1).T.to(device)
        tol = 1e-6
        u_pred_bound_list = list()
        u_train_bound_list = list()
        u_pred_ini_list = list()
        u_train_ini_list = list()
        
        if x_b_train.shape[0] != 0:
            # apply boundary conditions
            diff.apply_bc(net, x_b_train, u_b_train, u_pred_bound_list, u_train_bound_list)
        if x_u_train.shape[0] != 0:
            # apply initial conditions
            diff.apply_ic(net, x_u_train, u_train, u_pred_ini_list, u_train_ini_list)
        u_pred_bound_vars = torch.cat(u_pred_bound_list,0)
        u_train_bound_vars = torch.cat(u_train_bound_list,0)
        u_pred_ini_vars = torch.cat(u_pred_ini_list,0)
        u_train_ini_vars = torch.cat(u_train_ini_list,0)

        assert not torch.isnan(u_pred_bound_vars).any()
        assert not torch.isnan(u_train_bound_vars).any()

        loss_bound = torch.mean(abs(u_pred_bound_vars - u_train_bound_vars)**2)
        loss_ini = torch.mean(abs(u_pred_ini_vars - u_train_ini_vars)**2)
        
        # residual calculation for temporal weights
        res = diff.compute_residual(net,x_f_train)
        
        loss_res = torch.mean(abs(res)**2)
        loss_vars = loss_ini + loss_bound
        loss_reg = regularization(net, order_regularizer)

        loss_v = lambda_residual * loss_vars + 2 * loss_res + lambda_reg * loss_reg
        print("Total loss:", loss_v.detach().cpu().numpy().round(6), "|Boundary loss: ", torch.log10(loss_bound).detach().cpu().numpy().round(4), "|Initial residual: ", 
              torch.log10(loss_ini).detach().cpu().numpy().round(4), "|PDE loss ", torch.log10(loss_res).detach().cpu().numpy().round(6))
        return loss_v, loss_vars, loss_res
    
def regularization(model, p):
    reg_loss = 0
    for name, param in model.named_parameters():
        if 'weight' in name:
            reg_loss += torch.norm(param, p)
    return reg_loss

# %%
import ChooseOptimizer as co
learn_rate = 0.01
class Net:
    def __init__(self, model = "diff"):
        device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
        
        # build model
        if model == "diff":
            self.model = DiffNet(
               input_size=3,
               hidden_size=256,
               output_size=1,
               depth=6,
               act=torch.nn.Tanh).to(device)
        elif model == "siren":
            self.model = Siren(in_features=4, 
                               out_features=2, 
                               hidden_features=51, 
                               hidden_layers=11, 
                               outermost_linear=True).to(device)
        elif model == "complex":
            self.model = ComplexHeatEquationNet().to(device)
        self.model_input = {}
        self.gt = {}

        # optimizer
        params_lbfgs = (self.model.parameters(), learn_rate, 100, None, 100, 1e-7, 1e-7, "strong_wolfe")
        self.optimizer = self.configure_optimizers("LBFGS", *params_lbfgs)
        self.iter = 0

    def configure_optimizers(self, optimizer_name, *params):
        return co.choose_optimizer(optimizer_name, *params)
        
    def train(self, diff, epochs, training_set, verbose = True, freq = 1):
        train_losses = list([np.inf, np.inf, np.inf])
        # unpack training data in different sets
        training_coll = training_set.data_coll
        training_boundary = training_set.data_boundary
        training_initial_internal = training_set.data_initial_internal

        for epoch in range(epochs):
            if verbose and epoch % freq == 0:
                print(f"=============== {epoch} ===============")

            for step, ((x_coll_train, u_coll_train), (x_b_train, u_b_train), (x_u_train, u_train)) in enumerate(zip(training_coll, training_boundary, training_initial_internal)):

                x_coll_train = x_coll_train.to(device)
                x_b_train = x_b_train.to(device)
                u_b_train = u_b_train.to(device)
                x_u_train = x_u_train.to(device)
                u_train = u_train.to(device)

                def closure():
                    self.optimizer.zero_grad()
                    loss_f, loss_vars, loss_pde = CustomLoss().forward(diff, self.model, x_u_train, u_train, x_b_train, u_b_train, x_coll_train, training_set)
                    loss_f.backward()
                    train_losses[0] = loss_f
                    train_losses[1] = loss_vars
                    train_losses[2] = loss_pde
                    return loss_f

                self.optimizer.step(closure=closure)
        return train_losses

# %% [markdown]
# Using the xavier initialization for the balance of the weights

# %%
def init_xavier(model):
    def init_weights(m):
        if type(m) == nn.Linear and m.weight.requires_grad and m.bias.requires_grad:
            # gain = nn.init.calculate_gain('tanh')
            gain = 1
            torch.nn.init.xavier_uniform_(m.weight, gain=gain)
            torch.nn.init.uniform_(m.bias, 0, 1)

            # torch.nn.init.xavier_uniform_(m.bias)
            # m.bias.data.fill_(0)

    model.apply(init_weights)
    
def init_kaiming(model):
    def init_weights(m):
        if type(m) == nn.Linear and m.weight.requires_grad and m.bias.requires_grad:
            # gain = nn.init.calculate_gain('tanh')
            gain = 1
            torch.nn.init.kaiming_uniform_(m.weight, nonlinearity='tanh')
            torch.nn.init.uniform_(m.bias, 0, 1)

            # torch.nn.init.xavier_uniform_(m.bias)
            # m.bias.data.fill_(0)

    model.apply(init_weights)

# %%
# dataset creation
N_b_train = 2048
N_i_train = 2048
N_coll_train = 4096
N_int_train = 2048
diff = DiffClass()
training_set = DefineDataset(diff, N_coll_train, N_b_train, N_i_train, N_int_train, batches = 4096, random_seed=32, shuffle=True)
training_set.assemble_dataset()
# model creation 
net = Net(model="diff") 
init_kaiming(net.model)
# torch compile the model
#net.model = torch.compile(net.model)
net.train(diff, 100, training_set=training_set)
# Out:
# None
# sobol
# torch.Size([4096, 3])
# sobol
# sobol
# sobol
# sobol
# boundary_values: torch.Size([8192, 1, 1])
# boundary shapes: torch.Size([8192, 3]), torch.Size([8192, 1, 1])
# sobol
# torch.Size([2048])
# torch.Size([2048, 3])
# torch.Size([2048])
# ##############################################
# collocation:  tensor([[0.9766, 0.2441, 0.6348],
#         [2.9766, 0.7441, 0.1348],
#         [3.9766, 0.4941, 0.3848],
#         [1.9766, 0.9941, 0.8848],
#         [1.4766, 0.3691, 0.0098],
#         [3.4766, 0.8691, 0.5098],
#         [2.4766, 0.1191, 0.7598],
#         [0.4766, 0.6191, 0.2598],
#         [0.3516, 0.0879, 0.1660]]) torch.Size([4096, 3]) torch.Size([4096, 1])
#  collocation_max:  tensor([3.9990, 0.9999, 0.9998])
#  collocation_min:  tensor([0.0010, 0.0002, 0.0002])
# Saved points dataset
# =============== 0 ===============
# Total loss: 73.32568 |Boundary loss:  0.1508 |Initial residual:  -0.3397 |PDE loss  1.552991
# Total loss: 73.286415 |Boundary loss:  0.1508 |Initial residual:  -0.3398 |PDE loss  1.552753
# Total loss: 73.10953 |Boundary loss:  0.1509 |Initial residual:  -0.3403 |PDE loss  1.551677
# Total loss: 71.18488 |Boundary loss:  0.1518 |Initial residual:  -0.3455 |PDE loss  1.539799
# Total loss: 54.00415 |Boundary loss:  0.1607 |Initial residual:  -0.3981 |PDE loss  1.416278
# Total loss: 53.2633 |Boundary loss:  0.1609 |Initial residual:  -0.4007 |PDE loss  1.41008
# Total loss: 50.00914 |Boundary loss:  0.1618 |Initial residual:  -0.4129 |PDE loss  1.381759
# Total loss: 23.434675 |Boundary loss:  0.1739 |Initial residual:  -0.5493 |PDE loss  1.034625
# Total loss: 23.197826 |Boundary loss:  0.1735 |Initial residual:  -0.5513 |PDE loss  1.029904
# Total loss: 21.162338 |Boundary loss:  0.17 |Initial residual:  -0.5699 |PDE loss  0.987084
# Total loss: 10.137454 |Boundary loss:  0.138 |Initial residual:  -0.7529 |PDE loss  0.632808
# Total loss: 10.104167 |Boundary loss:  0.1372 |Initial residual:  -0.7541 |PDE loss  0.631273
# Total loss: 9.811274 |Boundary loss:  0.13 |Initial residual:  -0.7645 |PDE loss  0.617544
# Total loss: 7.511836 |Boundary loss:  0.0555 |Initial residual:  -0.8696 |PDE loss  0.494195
# Total loss: 7.451305 |Boundary loss:  0.0533 |Initial residual:  -0.8747 |PDE loss  0.490472
# Total loss: 7.186302 |Boundary loss:  0.0434 |Initial residual:  -0.8977 |PDE loss  0.473827
# Total loss: 5.08177 |Boundary loss:  -0.0715 |Initial residual:  -1.161 |PDE loss  0.318536
# Total loss: 5.031285 |Boundary loss:  -0.0765 |Initial residual:  -1.1676 |PDE loss  0.314364
# Total loss: 4.816292 |Boundary loss:  -0.0991 |Initial residual:  -1.197 |PDE loss  0.296312
# Total loss: 4.78352 |Boundary loss:  -0.1025 |Initial residual:  -1.2019 |PDE loss  0.293464
# Total loss: 4.502924 |Boundary loss:  -0.1335 |Initial residual:  -1.245 |PDE loss  0.268421
# Total loss: 3.027924 |Boundary loss:  -0.5067 |Initial residual:  -1.2688 |PDE loss  0.124292
# Total loss: 3.019543 |Boundary loss:  -0.509 |Initial residual:  -1.2676 |PDE loss  0.123165
# Total loss: 2.94878 |Boundary loss:  -0.5296 |Initial residual:  -1.257 |PDE loss  0.113621
# Total loss: 2.9389 |Boundary loss:  -0.5325 |Initial residual:  -1.2553 |PDE loss  0.112261
# Total loss: 2.895257 |Boundary loss:  -0.5458 |Initial residual:  -1.2475 |PDE loss  0.106208
# Total loss: 2.50813 |Boundary loss:  -0.7014 |Initial residual:  -1.1507 |PDE loss  0.048942
# Total loss: 2.498231 |Boundary loss:  -0.705 |Initial residual:  -1.149 |PDE loss  0.047284
# Total loss: 2.454526 |Boundary loss:  -0.7214 |Initial residual:  -1.1413 |PDE loss  0.039883
# Total loss: 2.06865 |Boundary loss:  -0.912 |Initial residual:  -1.0539 |PDE loss  -0.032022
# Total loss: 2.057651 |Boundary loss:  -0.916 |Initial residual:  -1.0547 |PDE loss  -0.034296
# Total loss: 1.963165 |Boundary loss:  -0.9526 |Initial residual:  -1.0622 |PDE loss  -0.054292
# Total loss: 1.438482 |Boundary loss:  -1.3415 |Initial residual:  -1.1385 |PDE loss  -0.180376
# Total loss: 1.430869 |Boundary loss:  -1.3436 |Initial residual:  -1.14 |PDE loss  -0.182736
# Total loss: 1.371229 |Boundary loss:  -1.3624 |Initial residual:  -1.1527 |PDE loss  -0.201533
# Total loss: 1.368636 |Boundary loss:  -1.3635 |Initial residual:  -1.1542 |PDE loss  -0.20231
# Total loss: 1.357216 |Boundary loss:  -1.3683 |Initial residual:  -1.1608 |PDE loss  -0.205741
# Total loss: 1.260101 |Boundary loss:  -1.4212 |Initial residual:  -1.2343 |PDE loss  -0.235119
# Total loss: 1.258586 |Boundary loss:  -1.422 |Initial residual:  -1.2359 |PDE loss  -0.235579
# Total loss: 1.245437 |Boundary loss:  -1.4294 |Initial residual:  -1.2503 |PDE loss  -0.239565
# Total loss: 1.161597 |Boundary loss:  -1.5022 |Initial residual:  -1.3893 |PDE loss  -0.263872
# Total loss: 1.160757 |Boundary loss:  -1.5027 |Initial residual:  -1.3904 |PDE loss  -0.26415
# Total loss: 1.157009 |Boundary loss:  -1.5053 |Initial residual:  -1.3952 |PDE loss  -0.265394
# Total loss: 1.120176 |Boundary loss:  -1.5331 |Initial residual:  -1.4469 |PDE loss  -0.277722
# Total loss: 1.117196 |Boundary loss:  -1.5353 |Initial residual:  -1.4501 |PDE loss  -0.27878
# Total loss: 1.104149 |Boundary loss:  -1.5455 |Initial residual:  -1.4644 |PDE loss  -0.283435
# Total loss: 1.000328 |Boundary loss:  -1.6575 |Initial residual:  -1.6198 |PDE loss  -0.321333
# Total loss: 0.997416 |Boundary loss:  -1.6601 |Initial residual:  -1.6229 |PDE loss  -0.322522
# Total loss: 0.973266 |Boundary loss:  -1.6833 |Initial residual:  -1.6508 |PDE loss  -0.332459
# Total loss: 0.971307 |Boundary loss:  -1.6855 |Initial residual:  -1.6533 |PDE loss  -0.333269
# Total loss: 0.954479 |Boundary loss:  -1.7047 |Initial residual:  -1.675 |PDE loss  -0.340271
# Total loss: 0.863115 |Boundary loss:  -1.8789 |Initial residual:  -1.8794 |PDE loss  -0.378461
# Total loss: 0.862552 |Boundary loss:  -1.8797 |Initial residual:  -1.8804 |PDE loss  -0.378724
# Total loss: 0.860081 |Boundary loss:  -1.8837 |Initial residual:  -1.8848 |PDE loss  -0.379879
# Total loss: 0.840096 |Boundary loss:  -1.9253 |Initial residual:  -1.9278 |PDE loss  -0.389122
# Total loss: 0.839531 |Boundary loss:  -1.9262 |Initial residual:  -1.929 |PDE loss  -0.389392
# Total loss: 0.83702 |Boundary loss:  -1.9301 |Initial residual:  -1.9344 |PDE loss  -0.390596
# Total loss: 0.82424 |Boundary loss:  -1.9494 |Initial residual:  -1.9642 |PDE loss  -0.396777
# Total loss: 0.822828 |Boundary loss:  -1.951 |Initial residual:  -1.9672 |PDE loss  -0.397479
# Total loss: 0.810658 |Boundary loss:  -1.9634 |Initial residual:  -1.9951 |PDE loss  -0.403587
# Total loss: 0.741057 |Boundary loss:  -1.9437 |Initial residual:  -2.2543 |PDE loss  -0.441229
# Total loss: 0.739846 |Boundary loss:  -1.9434 |Initial residual:  -2.2555 |PDE loss  -0.441952
# Total loss: 0.734878 |Boundary loss:  -1.9416 |Initial residual:  -2.2607 |PDE loss  -0.444934
# Total loss: 0.734385 |Boundary loss:  -1.9414 |Initial residual:  -2.2619 |PDE loss  -0.445227
# Total loss: 0.730117 |Boundary loss:  -1.9393 |Initial residual:  -2.2719 |PDE loss  -0.447776
# Total loss: 0.703704 |Boundary loss:  -1.9084 |Initial residual:  -2.3598 |PDE loss  -0.464079
# Total loss: 0.703499 |Boundary loss:  -1.9087 |Initial residual:  -2.3604 |PDE loss  -0.464201
# Total loss: 0.702402 |Boundary loss:  -1.91 |Initial residual:  -2.3635 |PDE loss  -0.464852
# Total loss: 0.696967 |Boundary loss:  -1.9169 |Initial residual:  -2.3797 |PDE loss  -0.468083
# Total loss: 0.69634 |Boundary loss:  -1.9181 |Initial residual:  -2.3808 |PDE loss  -0.468454
# Total loss: 0.690934 |Boundary loss:  -1.9291 |Initial residual:  -2.3912 |PDE loss  -0.471663
# Total loss: 0.659778 |Boundary loss:  -2.0374 |Initial residual:  -2.4736 |PDE loss  -0.489964
# Total loss: 0.659382 |Boundary loss:  -2.0391 |Initial residual:  -2.4742 |PDE loss  -0.490202
# Total loss: 0.65618 |Boundary loss:  -2.0545 |Initial residual:  -2.4797 |PDE loss  -0.492114
# Total loss: 0.655939 |Boundary loss:  -2.0558 |Initial residual:  -2.48 |PDE loss  -0.492256
# Total loss: 0.654072 |Boundary loss:  -2.0663 |Initial residual:  -2.4827 |PDE loss  -0.493362
# Total loss: 0.641343 |Boundary loss:  -2.1667 |Initial residual:  -2.5065 |PDE loss  -0.500715
# Total loss: 0.64121 |Boundary loss:  -2.1675 |Initial residual:  -2.5066 |PDE loss  -0.500797
# Total loss: 0.640614 |Boundary loss:  -2.1712 |Initial residual:  -2.5074 |PDE loss  -0.501164
# Total loss: 0.637561 |Boundary loss:  -2.1905 |Initial residual:  -2.5114 |PDE loss  -0.503048
# Total loss: 0.637222 |Boundary loss:  -2.192 |Initial residual:  -2.5122 |PDE loss  -0.503264
# Total loss: 0.635719 |Boundary loss:  -2.1985 |Initial residual:  -2.5155 |PDE loss  -0.504222
# Total loss: 0.622419 |Boundary loss:  -2.2608 |Initial residual:  -2.5501 |PDE loss  -0.512779
# Total loss: 0.622077 |Boundary loss:  -2.2617 |Initial residual:  -2.5523 |PDE loss  -0.513003
# Total loss: 0.619107 |Boundary loss:  -2.2697 |Initial residual:  -2.5717 |PDE loss  -0.514952
# Total loss: 0.599558 |Boundary loss:  -2.305 |Initial residual:  -2.744 |PDE loss  -0.528122
# Total loss: 0.59923 |Boundary loss:  -2.3052 |Initial residual:  -2.7456 |PDE loss  -0.528355
# Total loss: 0.596978 |Boundary loss:  -2.3063 |Initial residual:  -2.7575 |PDE loss  -0.529964
# Total loss: 0.59671 |Boundary loss:  -2.3064 |Initial residual:  -2.7594 |PDE loss  -0.530155
# Total loss: 0.595524 |Boundary loss:  -2.3066 |Initial residual:  -2.7679 |PDE loss  -0.531002
# Total loss: 0.584966 |Boundary loss:  -2.3055 |Initial residual:  -2.8461 |PDE loss  -0.538657
# Total loss: 0.584675 |Boundary loss:  -2.3055 |Initial residual:  -2.8479 |PDE loss  -0.538872
# Total loss: 0.583385 |Boundary loss:  -2.3051 |Initial residual:  -2.8558 |PDE loss  -0.539826
# Total loss: 0.576984 |Boundary loss:  -2.302 |Initial residual:  -2.8875 |PDE loss  -0.544623
# Total loss: 0.576535 |Boundary loss:  -2.3021 |Initial residual:  -2.8878 |PDE loss  -0.544962
# Total loss: 0.57457 |Boundary loss:  -2.3027 |Initial residual:  -2.8891 |PDE loss  -0.546454
# Total loss: 0.559032 |Boundary loss:  -2.3033 |Initial residual:  -2.8608 |PDE loss  -0.558556
# Total loss: 0.558618 |Boundary loss:  -2.3033 |Initial residual:  -2.8597 |PDE loss  -0.558884
# Total loss: 0.555207 |Boundary loss:  -2.3028 |Initial residual:  -2.8483 |PDE loss  -0.561608
# Total loss: 0.554928 |Boundary loss:  -2.303 |Initial residual:  -2.8475 |PDE loss  -0.56183
# Total loss: 0.553701 |Boundary loss:  -2.3037 |Initial residual:  -2.8436 |PDE loss  -0.562805
# Total loss: 0.547796 |Boundary loss:  -2.3074 |Initial residual:  -2.8189 |PDE loss  -0.567551
# Total loss: 0.547502 |Boundary loss:  -2.308 |Initial residual:  -2.8181 |PDE loss  -0.567784
# Total loss: 0.54621 |Boundary loss:  -2.3104 |Initial residual:  -2.8143 |PDE loss  -0.568811
# Total loss: 0.535442 |Boundary loss:  -2.3345 |Initial residual:  -2.7713 |PDE loss  -0.577477
# Total loss: 0.535171 |Boundary loss:  -2.3349 |Initial residual:  -2.7707 |PDE loss  -0.577697
# Total loss: 0.533994 |Boundary loss:  -2.3369 |Initial residual:  -2.768 |PDE loss  -0.578656
# Total loss: 0.526517 |Boundary loss:  -2.3536 |Initial residual:  -2.7412 |PDE loss  -0.584799
# Total loss: 0.526382 |Boundary loss:  -2.3541 |Initial residual:  -2.7413 |PDE loss  -0.584907
# Total loss: 0.525473 |Boundary loss:  -2.3579 |Initial residual:  -2.7418 |PDE loss  -0.585633
# Total loss: 0.518794 |Boundary loss:  -2.3936 |Initial residual:  -2.7435 |PDE loss  -0.590956
# Total loss: 0.518659 |Boundary loss:  -2.3942 |Initial residual:  -2.7435 |PDE loss  -0.591066
# Total loss: 0.518062 |Boundary loss:  -2.3968 |Initial residual:  -2.7432 |PDE loss  -0.591552
# Total loss: 0.512778 |Boundary loss:  -2.423 |Initial residual:  -2.7376 |PDE loss  -0.595874
# Total loss: 0.512533 |Boundary loss:  -2.424 |Initial residual:  -2.7382 |PDE loss  -0.596074
# Total loss: 0.511466 |Boundary loss:  -2.4286 |Initial residual:  -2.7405 |PDE loss  -0.596947
# Total loss: 0.503829 |Boundary loss:  -2.4701 |Initial residual:  -2.7346 |PDE loss  -0.603279
# Total loss: 0.503705 |Boundary loss:  -2.4704 |Initial residual:  -2.7344 |PDE loss  -0.603385
# Total loss: 0.503159 |Boundary loss:  -2.472 |Initial residual:  -2.7334 |PDE loss  -0.603854
# Total loss: 0.50052 |Boundary loss:  -2.4801 |Initial residual:  -2.7269 |PDE loss  -0.606132
# Total loss: 0.50038 |Boundary loss:  -2.4804 |Initial residual:  -2.7271 |PDE loss  -0.606252
# Total loss: 0.499167 |Boundary loss:  -2.4834 |Initial residual:  -2.7285 |PDE loss  -0.607292
# Total loss: 0.491999 |Boundary loss:  -2.5039 |Initial residual:  -2.7292 |PDE loss  -0.613502
# Total loss: 0.491903 |Boundary loss:  -2.5042 |Initial residual:  -2.7303 |PDE loss  -0.613581
# Total loss: 0.491488 |Boundary loss:  -2.5056 |Initial residual:  -2.7352 |PDE loss  -0.613923
# Total loss: 0.489721 |Boundary loss:  -2.5127 |Initial residual:  -2.7628 |PDE loss  -0.615357
# Total loss: 1.031664 |Boundary loss:  -2.483 |Initial residual:  -2.7702 |PDE loss  -0.289596
# Total loss: 1.030579 |Boundary loss:  -2.4859 |Initial residual:  -2.7831 |PDE loss  -0.290024
# Total loss: 1.030437 |Boundary loss:  -2.4862 |Initial residual:  -2.7849 |PDE loss  -0.290081
# Total loss: 1.029289 |Boundary loss:  -2.4881 |Initial residual:  -2.8003 |PDE loss  -0.290537
# Total loss: 1.020662 |Boundary loss:  -2.5034 |Initial residual:  -2.9656 |PDE loss  -0.293948
# Total loss: 1.020409 |Boundary loss:  -2.5034 |Initial residual:  -2.9698 |PDE loss  -0.294051
# Total loss: 1.018816 |Boundary loss:  -2.5037 |Initial residual:  -2.9975 |PDE loss  -0.294703
# Total loss: 1.007671 |Boundary loss:  -2.4987 |Initial residual:  -3.3083 |PDE loss  -0.299293
# Total loss: 1.007355 |Boundary loss:  -2.4991 |Initial residual:  -3.3155 |PDE loss  -0.299425
# Total loss: 1.004595 |Boundary loss:  -2.5019 |Initial residual:  -3.3774 |PDE loss  -0.300584
# Total loss: 0.985469 |Boundary loss:  -2.503 |Initial residual:  -3.2421 |PDE loss  -0.309026
# Total loss: 0.985024 |Boundary loss:  -2.5029 |Initial residual:  -3.2354 |PDE loss  -0.309228
# Total loss: 0.981291 |Boundary loss:  -2.5021 |Initial residual:  -3.178 |PDE loss  -0.310922
# Total loss: 0.964698 |Boundary loss:  -2.4922 |Initial residual:  -2.9035 |PDE loss  -0.318655
# Total loss: 0.963513 |Boundary loss:  -2.4918 |Initial residual:  -2.8907 |PDE loss  -0.319209
# Total loss: 0.953239 |Boundary loss:  -2.4875 |Initial residual:  -2.7812 |PDE loss  -0.324071
# Total loss: 0.900512 |Boundary loss:  -2.3366 |Initial residual:  -2.0784 |PDE loss  -0.352834
# Total loss: 0.899988 |Boundary loss:  -2.3371 |Initial residual:  -2.0791 |PDE loss  -0.353081
# Total loss: 0.897672 |Boundary loss:  -2.3393 |Initial residual:  -2.0823 |PDE loss  -0.354175
# Total loss: 0.877447 |Boundary loss:  -2.3615 |Initial residual:  -2.1167 |PDE loss  -0.363786
# Total loss: 0.876754 |Boundary loss:  -2.362 |Initial residual:  -2.1176 |PDE loss  -0.364124
# Total loss: 0.870749 |Boundary loss:  -2.3654 |Initial residual:  -2.1257 |PDE loss  -0.367061
# Total loss: 0.834044 |Boundary loss:  -2.3854 |Initial residual:  -2.191 |PDE loss  -0.385374
# Total loss: 0.833465 |Boundary loss:  -2.3855 |Initial residual:  -2.1916 |PDE loss  -0.385674
# Total loss: 0.828526 |Boundary loss:  -2.3859 |Initial residual:  -2.1971 |PDE loss  -0.388244
# Total loss: 0.802258 |Boundary loss:  -2.379 |Initial residual:  -2.2296 |PDE loss  -0.402203
# Total loss: 0.801836 |Boundary loss:  -2.379 |Initial residual:  -2.2304 |PDE loss  -0.402429
# Total loss: 0.799966 |Boundary loss:  -2.3792 |Initial residual:  -2.2336 |PDE loss  -0.403431
# Total loss: 0.78319 |Boundary loss:  -2.3767 |Initial residual:  -2.2647 |PDE loss  -0.41254
# Total loss: 0.782632 |Boundary loss:  -2.3765 |Initial residual:  -2.265 |PDE loss  -0.412852
# Total loss: 0.780173 |Boundary loss:  -2.3758 |Initial residual:  -2.2665 |PDE loss  -0.414229
# Total loss: 0.759421 |Boundary loss:  -2.3641 |Initial residual:  -2.2807 |PDE loss  -0.426051
# Total loss: 0.758975 |Boundary loss:  -2.3643 |Initial residual:  -2.2822 |PDE loss  -0.426298
# Total loss: 0.757015 |Boundary loss:  -2.3653 |Initial residual:  -2.2888 |PDE loss  -0.427384
# Total loss: 0.747734 |Boundary loss:  -2.3697 |Initial residual:  -2.3254 |PDE loss  -0.432539
# Total loss: 0.747228 |Boundary loss:  -2.3697 |Initial residual:  -2.3261 |PDE loss  -0.432833
# Total loss: 0.742862 |Boundary loss:  -2.3699 |Initial residual:  -2.3319 |PDE loss  -0.435371
# Total loss: 0.717649 |Boundary loss:  -2.3599 |Initial residual:  -2.3802 |PDE loss  -0.450313
# Total loss: 0.717365 |Boundary loss:  -2.3605 |Initial residual:  -2.382 |PDE loss  -0.450472
# Total loss: 0.716112 |Boundary loss:  -2.3633 |Initial residual:  -2.3901 |PDE loss  -0.451176
# Total loss: 0.710092 |Boundary loss:  -2.3776 |Initial residual:  -2.4354 |PDE loss  -0.45455
# Total loss: 0.709669 |Boundary loss:  -2.3781 |Initial residual:  -2.4365 |PDE loss  -0.454803
# Total loss: 0.707803 |Boundary loss:  -2.38 |Initial residual:  -2.4415 |PDE loss  -0.455922
# Total loss: 0.691675 |Boundary loss:  -2.3945 |Initial residual:  -2.4905 |PDE loss  -0.465713
# Total loss: 0.691306 |Boundary loss:  -2.3948 |Initial residual:  -2.4918 |PDE loss  -0.465939
# Total loss: 0.689679 |Boundary loss:  -2.3963 |Initial residual:  -2.4978 |PDE loss  -0.466936
# Total loss: 0.675762 |Boundary loss:  -2.4066 |Initial residual:  -2.5626 |PDE loss  -0.475537
# Total loss: 0.6754 |Boundary loss:  -2.4067 |Initial residual:  -2.5632 |PDE loss  -0.475769
# Total loss: 0.673817 |Boundary loss:  -2.4071 |Initial residual:  -2.5658 |PDE loss  -0.476785
# Total loss: 0.661425 |Boundary loss:  -2.4085 |Initial residual:  -2.5911 |PDE loss  -0.484817
# Total loss: 0.661169 |Boundary loss:  -2.4088 |Initial residual:  -2.5923 |PDE loss  -0.48498
# Total loss: 0.660042 |Boundary loss:  -2.4105 |Initial residual:  -2.5974 |PDE loss  -0.485699
# Total loss: 0.654675 |Boundary loss:  -2.4192 |Initial residual:  -2.6259 |PDE loss  -0.48912
# Total loss: 0.654406 |Boundary loss:  -2.4198 |Initial residual:  -2.6271 |PDE loss  -0.489293
# Total loss: 0.653219 |Boundary loss:  -2.4221 |Initial residual:  -2.6327 |PDE loss  -0.490054
# Total loss: 0.647437 |Boundary loss:  -2.4346 |Initial residual:  -2.6638 |PDE loss  -0.493771
# Total loss: 0.647084 |Boundary loss:  -2.4354 |Initial residual:  -2.6656 |PDE loss  -0.493999
# Total loss: 0.645532 |Boundary loss:  -2.4387 |Initial residual:  -2.6741 |PDE loss  -0.495004
# Total loss: 0.632774 |Boundary loss:  -2.4686 |Initial residual:  -2.7692 |PDE loss  -0.503296
# Total loss: 0.632486 |Boundary loss:  -2.4692 |Initial residual:  -2.7715 |PDE loss  -0.503486
# Total loss: 0.630064 |Boundary loss:  -2.4733 |Initial residual:  -2.7922 |PDE loss  -0.505089
# Total loss: 0.629776 |Boundary loss:  -2.4737 |Initial residual:  -2.7948 |PDE loss  -0.50528
# Total loss: 0.628508 |Boundary loss:  -2.4756 |Initial residual:  -2.8064 |PDE loss  -0.506123
# Total loss: 0.618031 |Boundary loss:  -2.4844 |Initial residual:  -2.9347 |PDE loss  -0.513151
# Total loss: 0.617854 |Boundary loss:  -2.4844 |Initial residual:  -2.9366 |PDE loss  -0.513273
# Total loss: 0.616348 |Boundary loss:  -2.4842 |Initial residual:  -2.9531 |PDE loss  -0.51431
# Total loss: 0.616113 |Boundary loss:  -2.4844 |Initial residual:  -2.9561 |PDE loss  -0.514471
# Total loss: 0.614091 |Boundary loss:  -2.4855 |Initial residual:  -2.9825 |PDE loss  -0.515856
# Total loss: 0.603512 |Boundary loss:  -2.4796 |Initial residual:  -3.151 |PDE loss  -0.523247
# Total loss: 0.603434 |Boundary loss:  -2.4798 |Initial residual:  -3.1508 |PDE loss  -0.523303
# Total loss: 0.603044 |Boundary loss:  -2.481 |Initial residual:  -3.1501 |PDE loss  -0.523579
# Total loss: 0.601158 |Boundary loss:  -2.487 |Initial residual:  -3.146 |PDE loss  -0.524921
# Total loss: 0.600996 |Boundary loss:  -2.4876 |Initial residual:  -3.1461 |PDE loss  -0.525035
# Total loss: 0.600282 |Boundary loss:  -2.49 |Initial residual:  -3.1465 |PDE loss  -0.525542
# Total loss: 0.59399 |Boundary loss:  -2.5094 |Initial residual:  -3.145 |PDE loss  -0.530046
# Total loss: 0.593834 |Boundary loss:  -2.5096 |Initial residual:  -3.145 |PDE loss  -0.53016
# Total loss: 0.592734 |Boundary loss:  -2.5114 |Initial residual:  -3.1442 |PDE loss  -0.530961
# Total loss: 0.585437 |Boundary loss:  -2.5107 |Initial residual:  -3.1207 |PDE loss  -0.53641
# Total loss: 0.585343 |Boundary loss:  -2.5107 |Initial residual:  -3.1205 |PDE loss  -0.53648
# Total loss: 0.584936 |Boundary loss:  -2.5107 |Initial residual:  -3.1194 |PDE loss  -0.536786
# Total loss: 0.582274 |Boundary loss:  -2.5079 |Initial residual:  -3.1049 |PDE loss  -0.538814
# Total loss: 0.582222 |Boundary loss:  -2.5078 |Initial residual:  -3.1049 |PDE loss  -0.538854
# Total loss: 0.581991 |Boundary loss:  -2.5073 |Initial residual:  -3.1052 |PDE loss  -0.53903
# Total loss: 0.580837 |Boundary loss:  -2.5046 |Initial residual:  -3.1064 |PDE loss  -0.53991
# Total loss: 0.580742 |Boundary loss:  -2.5046 |Initial residual:  -3.1066 |PDE loss  -0.539982
# Total loss: 0.579971 |Boundary loss:  -2.5049 |Initial residual:  -3.1076 |PDE loss  -0.54056
# Total loss: 0.57505 |Boundary loss:  -2.5054 |Initial residual:  -3.1137 |PDE loss  -0.544274
# Total loss: 0.574997 |Boundary loss:  -2.5055 |Initial residual:  -3.1137 |PDE loss  -0.544314
# Total loss: 0.574742 |Boundary loss:  -2.506 |Initial residual:  -3.1139 |PDE loss  -0.544505
# Total loss: 0.57346 |Boundary loss:  -2.5084 |Initial residual:  -3.1146 |PDE loss  -0.545468
# Total loss: 0.573307 |Boundary loss:  -2.5086 |Initial residual:  -3.1146 |PDE loss  -0.545583
# Total loss: 0.572635 |Boundary loss:  -2.51 |Initial residual:  -3.1145 |PDE loss  -0.546089
# Total loss: 0.568328 |Boundary loss:  -2.5183 |Initial residual:  -3.1106 |PDE loss  -0.54935
# Total loss: 0.56819 |Boundary loss:  -2.5185 |Initial residual:  -3.1104 |PDE loss  -0.549456
# Total loss: 0.567585 |Boundary loss:  -2.5196 |Initial residual:  -3.1091 |PDE loss  -0.549917
# Total loss: 0.563539 |Boundary loss:  -2.5255 |Initial residual:  -3.0937 |PDE loss  -0.553035
# Total loss: 0.56347 |Boundary loss:  -2.5256 |Initial residual:  -3.0935 |PDE loss  -0.553089
# Total loss: 0.563161 |Boundary loss:  -2.5261 |Initial residual:  -3.0928 |PDE loss  -0.553326
# Total loss: 0.561655 |Boundary loss:  -2.5287 |Initial residual:  -3.0885 |PDE loss  -0.55449
# Total loss: 0.561559 |Boundary loss:  -2.5289 |Initial residual:  -3.0883 |PDE loss  -0.554564
# Total loss: 0.561132 |Boundary loss:  -2.5298 |Initial residual:  -3.0873 |PDE loss  -0.554893
# Total loss: 0.55733 |Boundary loss:  -2.5396 |Initial residual:  -3.0765 |PDE loss  -0.55783
# Total loss: 0.557215 |Boundary loss:  -2.5399 |Initial residual:  -3.0764 |PDE loss  -0.557919
# Total loss: 0.55622 |Boundary loss:  -2.5428 |Initial residual:  -3.075 |PDE loss  -0.558687
# Total loss: 0.550729 |Boundary loss:  -2.5699 |Initial residual:  -3.0588 |PDE loss  -0.562913
# Total loss: 0.550643 |Boundary loss:  -2.5701 |Initial residual:  -3.0588 |PDE loss  -0.56298
# Total loss: 0.550263 |Boundary loss:  -2.5709 |Initial residual:  -3.0585 |PDE loss  -0.563278
# Total loss: 0.547166 |Boundary loss:  -2.5773 |Initial residual:  -3.0496 |PDE loss  -0.565729
# Total loss: 0.547083 |Boundary loss:  -2.5773 |Initial residual:  -3.0495 |PDE loss  -0.565796
# Total loss: 0.546801 |Boundary loss:  -2.5775 |Initial residual:  -3.0492 |PDE loss  -0.56602
# Total loss: 0.545292 |Boundary loss:  -2.5777 |Initial residual:  -3.0468 |PDE loss  -0.567231
# Total loss: 0.545139 |Boundary loss:  -2.5778 |Initial residual:  -3.0466 |PDE loss  -0.567354
# Total loss: 0.544462 |Boundary loss:  -2.5779 |Initial residual:  -3.0456 |PDE loss  -0.567898
# Total loss: 0.538784 |Boundary loss:  -2.5689 |Initial residual:  -3.0232 |PDE loss  -0.572564
# Total loss: 0.538666 |Boundary loss:  -2.5687 |Initial residual:  -3.0231 |PDE loss  -0.572661
# Total loss: 0.53815 |Boundary loss:  -2.5678 |Initial residual:  -3.0226 |PDE loss  -0.573086
# Total loss: 0.53575 |Boundary loss:  -2.5618 |Initial residual:  -3.0188 |PDE loss  -0.575078
# Total loss: 0.535647 |Boundary loss:  -2.5616 |Initial residual:  -3.0185 |PDE loss  -0.575164
# Total loss: 0.535014 |Boundary loss:  -2.5601 |Initial residual:  -3.0167 |PDE loss  -0.575692
# Total loss: 0.530569 |Boundary loss:  -2.5389 |Initial residual:  -2.9874 |PDE loss  -0.579509
# Total loss: 0.530497 |Boundary loss:  -2.5392 |Initial residual:  -2.9874 |PDE loss  -0.579568
# Total loss: 0.529868 |Boundary loss:  -2.5413 |Initial residual:  -2.9872 |PDE loss  -0.580076
# Total loss: 0.527283 |Boundary loss:  -2.5513 |Initial residual:  -2.9856 |PDE loss  -0.582164
# Total loss: 0.527152 |Boundary loss:  -2.5518 |Initial residual:  -2.9863 |PDE loss  -0.582268
# Total loss: 0.526429 |Boundary loss:  -2.5551 |Initial residual:  -2.9903 |PDE loss  -0.582843
# Total loss: 0.523237 |Boundary loss:  -2.5714 |Initial residual:  -3.0094 |PDE loss  -0.585382
# =============== 1 ===============
# Total loss: 0.621484 |Boundary loss:  -2.584 |Initial residual:  -3.0196 |PDE loss  -0.510096
# Total loss: 0.620848 |Boundary loss:  -2.5869 |Initial residual:  -3.0237 |PDE loss  -0.510525
# Total loss: 0.617515 |Boundary loss:  -2.6056 |Initial residual:  -3.0497 |PDE loss  -0.51276
# Total loss: 0.617356 |Boundary loss:  -2.6065 |Initial residual:  -3.0508 |PDE loss  -0.512867
# Total loss: 0.616596 |Boundary loss:  -2.611 |Initial residual:  -3.056 |PDE loss  -0.51338
# Total loss: 0.612823 |Boundary loss:  -2.6339 |Initial residual:  -3.0815 |PDE loss  -0.515935
# Total loss: 0.612404 |Boundary loss:  -2.6356 |Initial residual:  -3.0836 |PDE loss  -0.516224
# Total loss: 0.610559 |Boundary loss:  -2.6431 |Initial residual:  -3.0923 |PDE loss  -0.517501
# Total loss: 0.595054 |Boundary loss:  -2.7047 |Initial residual:  -3.1105 |PDE loss  -0.528485
# Total loss: 0.594602 |Boundary loss:  -2.7054 |Initial residual:  -3.1101 |PDE loss  -0.528815
# Total loss: 0.592619 |Boundary loss:  -2.708 |Initial residual:  -3.1079 |PDE loss  -0.530266
# Total loss: 0.576653 |Boundary loss:  -2.7044 |Initial residual:  -3.0326 |PDE loss  -0.542307
# Total loss: 0.576224 |Boundary loss:  -2.7041 |Initial residual:  -3.0306 |PDE loss  -0.542636
# Total loss: 0.574326 |Boundary loss:  -2.7026 |Initial residual:  -3.0212 |PDE loss  -0.544097
# Total loss: 0.557892 |Boundary loss:  -2.6674 |Initial residual:  -2.8977 |PDE loss  -0.557148
# Total loss: 0.557255 |Boundary loss:  -2.6674 |Initial residual:  -2.8952 |PDE loss  -0.557652
# Total loss: 0.551776 |Boundary loss:  -2.6669 |Initial residual:  -2.8719 |PDE loss  -0.562028
# Total loss: 0.521914 |Boundary loss:  -2.6396 |Initial residual:  -2.6272 |PDE loss  -0.587319
# Total loss: 0.521391 |Boundary loss:  -2.6392 |Initial residual:  -2.628 |PDE loss  -0.587757
# Total loss: 0.519102 |Boundary loss:  -2.6374 |Initial residual:  -2.6313 |PDE loss  -0.589679
# Total loss: 0.501247 |Boundary loss:  -2.6145 |Initial residual:  -2.6639 |PDE loss  -0.60498
# Total loss: 0.500707 |Boundary loss:  -2.6161 |Initial residual:  -2.6659 |PDE loss  -0.605436
# Total loss: 0.496007 |Boundary loss:  -2.6308 |Initial residual:  -2.6845 |PDE loss  -0.609418
# Total loss: 0.464129 |Boundary loss:  -2.7458 |Initial residual:  -2.848 |PDE loss  -0.637409
# Total loss: 0.463505 |Boundary loss:  -2.7469 |Initial residual:  -2.8507 |PDE loss  -0.637986
# Total loss: 0.458254 |Boundary loss:  -2.756 |Initial residual:  -2.8746 |PDE loss  -0.642861
# Total loss: 0.45765 |Boundary loss:  -2.7574 |Initial residual:  -2.8782 |PDE loss  -0.643422
# Total loss: 0.452467 |Boundary loss:  -2.7691 |Initial residual:  -2.9107 |PDE loss  -0.648264
# Total loss: 0.425695 |Boundary loss:  -2.8092 |Initial residual:  -3.1948 |PDE loss  -0.674172
# Total loss: 0.42546 |Boundary loss:  -2.8085 |Initial residual:  -3.1964 |PDE loss  -0.674413
# Total loss: 0.423585 |Boundary loss:  -2.8025 |Initial residual:  -3.2106 |PDE loss  -0.676342
# Total loss: 0.423323 |Boundary loss:  -2.8025 |Initial residual:  -3.2133 |PDE loss  -0.676609
# Total loss: 0.421063 |Boundary loss:  -2.8019 |Initial residual:  -3.2376 |PDE loss  -0.678913
# Total loss: 0.408239 |Boundary loss:  -2.7773 |Initial residual:  -3.4325 |PDE loss  -0.69229
# Total loss: 0.408123 |Boundary loss:  -2.7777 |Initial residual:  -3.433 |PDE loss  -0.692412
# Total loss: 0.407611 |Boundary loss:  -2.7796 |Initial residual:  -3.4354 |PDE loss  -0.69295
# Total loss: 0.405128 |Boundary loss:  -2.7897 |Initial residual:  -3.4444 |PDE loss  -0.695568
# Total loss: 0.404908 |Boundary loss:  -2.7911 |Initial residual:  -3.4448 |PDE loss  -0.6958
# Total loss: 0.40394 |Boundary loss:  -2.797 |Initial residual:  -3.446 |PDE loss  -0.696818
# Total loss: 0.395998 |Boundary loss:  -2.846 |Initial residual:  -3.4101 |PDE loss  -0.705331
# Total loss: 0.39586 |Boundary loss:  -2.8465 |Initial residual:  -3.4093 |PDE loss  -0.705483
# Total loss: 0.395249 |Boundary loss:  -2.8486 |Initial residual:  -3.406 |PDE loss  -0.706153
# Total loss: 0.39228 |Boundary loss:  -2.8569 |Initial residual:  -3.385 |PDE loss  -0.709434
# Total loss: 0.392116 |Boundary loss:  -2.8572 |Initial residual:  -3.3843 |PDE loss  -0.709616
# Total loss: 0.390703 |Boundary loss:  -2.8596 |Initial residual:  -3.3779 |PDE loss  -0.711189
# Total loss: 0.382747 |Boundary loss:  -2.8346 |Initial residual:  -3.296 |PDE loss  -0.720358
# Total loss: 0.382657 |Boundary loss:  -2.8345 |Initial residual:  -3.297 |PDE loss  -0.72046
# Total loss: 0.382047 |Boundary loss:  -2.8339 |Initial residual:  -3.3043 |PDE loss  -0.721149
# Total loss: 0.377867 |Boundary loss:  -2.8256 |Initial residual:  -3.3689 |PDE loss  -0.725906
# Total loss: 0.377766 |Boundary loss:  -2.826 |Initial residual:  -3.3699 |PDE loss  -0.726019
# Total loss: 0.377062 |Boundary loss:  -2.8294 |Initial residual:  -3.3768 |PDE loss  -0.726813
# Total loss: 0.373896 |Boundary loss:  -2.8454 |Initial residual:  -3.4096 |PDE loss  -0.730394
# Total loss: 0.373701 |Boundary loss:  -2.8464 |Initial residual:  -3.4115 |PDE loss  -0.730617
# Total loss: 0.372027 |Boundary loss:  -2.8544 |Initial residual:  -3.4279 |PDE loss  -0.732528
# Total loss: 0.363766 |Boundary loss:  -2.8895 |Initial residual:  -3.4814 |PDE loss  -0.742146
# Total loss: 0.363695 |Boundary loss:  -2.8895 |Initial residual:  -3.4811 |PDE loss  -0.742232
# Total loss: 0.363085 |Boundary loss:  -2.8895 |Initial residual:  -3.478 |PDE loss  -0.742967
# Total loss: 0.363008 |Boundary loss:  -2.8895 |Initial residual:  -3.4777 |PDE loss  -0.743059
# Total loss: 0.362668 |Boundary loss:  -2.8895 |Initial residual:  -3.4766 |PDE loss  -0.743469
# Total loss: 0.359737 |Boundary loss:  -2.8858 |Initial residual:  -3.4621 |PDE loss  -0.747036
# Total loss: 0.359683 |Boundary loss:  -2.8858 |Initial residual:  -3.4618 |PDE loss  -0.747103
# Total loss: 0.359441 |Boundary loss:  -2.8859 |Initial residual:  -3.4604 |PDE loss  -0.747397
# Total loss: 0.358249 |Boundary loss:  -2.886 |Initial residual:  -3.4514 |PDE loss  -0.748855
# Total loss: 0.358169 |Boundary loss:  -2.886 |Initial residual:  -3.4512 |PDE loss  -0.748952
# Total loss: 0.357816 |Boundary loss:  -2.8861 |Initial residual:  -3.4498 |PDE loss  -0.749383
# Total loss: 0.354747 |Boundary loss:  -2.8842 |Initial residual:  -3.4304 |PDE loss  -0.75317
# Total loss: 0.354674 |Boundary loss:  -2.8844 |Initial residual:  -3.4296 |PDE loss  -0.753259
# Total loss: 0.35435 |Boundary loss:  -2.8856 |Initial residual:  -3.426 |PDE loss  -0.753656
# Total loss: 0.351914 |Boundary loss:  -2.8952 |Initial residual:  -3.388 |PDE loss  -0.756675
# Total loss: 0.351819 |Boundary loss:  -2.8953 |Initial residual:  -3.3874 |PDE loss  -0.756793
# Total loss: 0.351403 |Boundary loss:  -2.8961 |Initial residual:  -3.3845 |PDE loss  -0.757309
# Total loss: 0.348042 |Boundary loss:  -2.9022 |Initial residual:  -3.3491 |PDE loss  -0.761525
# Total loss: 0.347964 |Boundary loss:  -2.9028 |Initial residual:  -3.3482 |PDE loss  -0.761622
# Total loss: 0.347618 |Boundary loss:  -2.9052 |Initial residual:  -3.3442 |PDE loss  -0.762052
# Total loss: 0.345923 |Boundary loss:  -2.9174 |Initial residual:  -3.3215 |PDE loss  -0.764172
# Total loss: 0.345817 |Boundary loss:  -2.9181 |Initial residual:  -3.321 |PDE loss  -0.764305
# Total loss: 0.345348 |Boundary loss:  -2.9212 |Initial residual:  -3.3188 |PDE loss  -0.76489
# Total loss: 0.34129 |Boundary loss:  -2.9475 |Initial residual:  -3.2948 |PDE loss  -0.769994
# Total loss: 0.341201 |Boundary loss:  -2.9479 |Initial residual:  -3.2946 |PDE loss  -0.770106
# Total loss: 0.340813 |Boundary loss:  -2.9495 |Initial residual:  -3.2935 |PDE loss  -0.770599
# Total loss: 0.338951 |Boundary loss:  -2.9567 |Initial residual:  -3.2873 |PDE loss  -0.772974
# Total loss: 0.338846 |Boundary loss:  -2.957 |Initial residual:  -3.2879 |PDE loss  -0.773108
# Total loss: 0.338358 |Boundary loss:  -2.9584 |Initial residual:  -3.2904 |PDE loss  -0.773729
# Total loss: 0.336124 |Boundary loss:  -2.9626 |Initial residual:  -3.3028 |PDE loss  -0.776588
# Total loss: 0.336041 |Boundary loss:  -2.9626 |Initial residual:  -3.3031 |PDE loss  -0.776694
# Total loss: 0.335636 |Boundary loss:  -2.9629 |Initial residual:  -3.305 |PDE loss  -0.777217
# Total loss: 0.333786 |Boundary loss:  -2.9619 |Initial residual:  -3.3132 |PDE loss  -0.77962
# Total loss: 0.33371 |Boundary loss:  -2.9619 |Initial residual:  -3.3137 |PDE loss  -0.779718
# Total loss: 0.333377 |Boundary loss:  -2.962 |Initial residual:  -3.3162 |PDE loss  -0.78015
# Total loss: 0.331202 |Boundary loss:  -2.96 |Initial residual:  -3.3314 |PDE loss  -0.782991
# Total loss: 0.331141 |Boundary loss:  -2.9599 |Initial residual:  -3.3316 |PDE loss  -0.783071
# Total loss: 0.330872 |Boundary loss:  -2.9592 |Initial residual:  -3.3328 |PDE loss  -0.783426
# Total loss: 0.329612 |Boundary loss:  -2.9544 |Initial residual:  -3.3367 |PDE loss  -0.785102
# Total loss: 0.32955 |Boundary loss:  -2.9544 |Initial residual:  -3.3368 |PDE loss  -0.785184
# Total loss: 0.329274 |Boundary loss:  -2.9544 |Initial residual:  -3.3371 |PDE loss  -0.785549
# Total loss: 0.327847 |Boundary loss:  -2.9537 |Initial residual:  -3.3347 |PDE loss  -0.787451
# Total loss: 0.327752 |Boundary loss:  -2.9534 |Initial residual:  -3.3345 |PDE loss  -0.787579
# Total loss: 0.327337 |Boundary loss:  -2.9521 |Initial residual:  -3.3334 |PDE loss  -0.788137
# Total loss: 0.324163 |Boundary loss:  -2.9331 |Initial residual:  -3.3053 |PDE loss  -0.792499
# Total loss: 0.324093 |Boundary loss:  -2.9332 |Initial residual:  -3.3045 |PDE loss  -0.792594
# Total loss: 0.323494 |Boundary loss:  -2.9339 |Initial residual:  -3.2974 |PDE loss  -0.793409
# Total loss: 0.321246 |Boundary loss:  -2.9359 |Initial residual:  -3.2544 |PDE loss  -0.796518
# Total loss: 0.321186 |Boundary loss:  -2.936 |Initial residual:  -3.2538 |PDE loss  -0.7966
# Total loss: 0.320923 |Boundary loss:  -2.9364 |Initial residual:  -3.2509 |PDE loss  -0.796962
# Total loss: 0.319622 |Boundary loss:  -2.938 |Initial residual:  -3.2342 |PDE loss  -0.798759
# Total loss: 0.319508 |Boundary loss:  -2.9383 |Initial residual:  -3.2336 |PDE loss  -0.798915
# Total loss: 0.318815 |Boundary loss:  -2.9403 |Initial residual:  -3.2298 |PDE loss  -0.799863
# Total loss: 0.316073 |Boundary loss:  -2.9476 |Initial residual:  -3.2092 |PDE loss  -0.803648
# Total loss: 0.315994 |Boundary loss:  -2.9478 |Initial residual:  -3.2092 |PDE loss  -0.803756
# Total loss: 0.315646 |Boundary loss:  -2.9486 |Initial residual:  -3.2094 |PDE loss  -0.804235
# Total loss: 0.312839 |Boundary loss:  -2.9519 |Initial residual:  -3.2105 |PDE loss  -0.808122
# Total loss: 0.312792 |Boundary loss:  -2.9519 |Initial residual:  -3.2108 |PDE loss  -0.808187
# Total loss: 0.312532 |Boundary loss:  -2.9519 |Initial residual:  -3.2127 |PDE loss  -0.808546
# Total loss: 0.311402 |Boundary loss:  -2.9512 |Initial residual:  -3.2222 |PDE loss  -0.810113
# Total loss: 0.311345 |Boundary loss:  -2.9512 |Initial residual:  -3.223 |PDE loss  -0.810191
# Total loss: 0.311095 |Boundary loss:  -2.9513 |Initial residual:  -3.2265 |PDE loss  -0.810534
# Total loss: 0.309286 |Boundary loss:  -2.9498 |Initial residual:  -3.2572 |PDE loss  -0.813029
# Total loss: 0.309247 |Boundary loss:  -2.9498 |Initial residual:  -3.2579 |PDE loss  -0.813083
# Total loss: 0.309071 |Boundary loss:  -2.95 |Initial residual:  -3.2609 |PDE loss  -0.813325
# Total loss: 0.308018 |Boundary loss:  -2.9511 |Initial residual:  -3.2801 |PDE loss  -0.814777
# Total loss: 0.307974 |Boundary loss:  -2.9511 |Initial residual:  -3.2807 |PDE loss  -0.814839
# Total loss: 0.307806 |Boundary loss:  -2.9509 |Initial residual:  -3.2832 |PDE loss  -0.815073
# Total loss: 0.306961 |Boundary loss:  -2.9498 |Initial residual:  -3.2948 |PDE loss  -0.816258
# Total loss: 0.306892 |Boundary loss:  -2.9499 |Initial residual:  -3.2952 |PDE loss  -0.816356
# Total loss: 0.306314 |Boundary loss:  -2.9511 |Initial residual:  -3.2973 |PDE loss  -0.817171
# Total loss: 0.516041 |Boundary loss:  -2.9607 |Initial residual:  -3.3147 |PDE loss  -0.589677
# Total loss: 0.51201 |Boundary loss:  -2.9609 |Initial residual:  -3.3162 |PDE loss  -0.593091
# Total loss: 0.480474 |Boundary loss:  -2.9565 |Initial residual:  -3.3209 |PDE loss  -0.620793
# Total loss: 0.479081 |Boundary loss:  -2.9571 |Initial residual:  -3.3221 |PDE loss  -0.622056
# Total loss: 0.47298 |Boundary loss:  -2.9595 |Initial residual:  -3.3265 |PDE loss  -0.62763
# Total loss: 0.424706 |Boundary loss:  -2.9732 |Initial residual:  -3.2881 |PDE loss  -0.674559
# Total loss: 0.42406 |Boundary loss:  -2.9726 |Initial residual:  -3.2875 |PDE loss  -0.675224
# Total loss: 0.421229 |Boundary loss:  -2.9695 |Initial residual:  -3.2847 |PDE loss  -0.678156
# Total loss: 0.398392 |Boundary loss:  -2.918 |Initial residual:  -3.2222 |PDE loss  -0.702694
# Total loss: 0.398037 |Boundary loss:  -2.9178 |Initial residual:  -3.2214 |PDE loss  -0.703085
# Total loss: 0.396478 |Boundary loss:  -2.9167 |Initial residual:  -3.2172 |PDE loss  -0.704806
# Total loss: 0.383864 |Boundary loss:  -2.8992 |Initial residual:  -3.1615 |PDE loss  -0.719065
# Total loss: 0.38358 |Boundary loss:  -2.8993 |Initial residual:  -3.1615 |PDE loss  -0.719388
# Total loss: 0.382328 |Boundary loss:  -2.8994 |Initial residual:  -3.1614 |PDE loss  -0.720815
# Total loss: 0.371802 |Boundary loss:  -2.899 |Initial residual:  -3.1583 |PDE loss  -0.73301
# Total loss: 0.371517 |Boundary loss:  -2.8992 |Initial residual:  -3.158 |PDE loss  -0.733344
# Total loss: 0.370264 |Boundary loss:  -2.9 |Initial residual:  -3.1562 |PDE loss  -0.73482
# Total loss: 0.364298 |Boundary loss:  -2.9035 |Initial residual:  -3.1454 |PDE loss  -0.741922
# Total loss: 0.363978 |Boundary loss:  -2.904 |Initial residual:  -3.1456 |PDE loss  -0.742304
# Total loss: 0.362568 |Boundary loss:  -2.9061 |Initial residual:  -3.1464 |PDE loss  -0.743989
# Total loss: 0.350906 |Boundary loss:  -2.9238 |Initial residual:  -3.1502 |PDE loss  -0.758196
# Total loss: 0.350587 |Boundary loss:  -2.9246 |Initial residual:  -3.1506 |PDE loss  -0.75859
# Total loss: 0.347938 |Boundary loss:  -2.9314 |Initial residual:  -3.1535 |PDE loss  -0.761873
# Total loss: 0.34765 |Boundary loss:  -2.9321 |Initial residual:  -3.1536 |PDE loss  -0.762231
# Total loss: 0.346382 |Boundary loss:  -2.935 |Initial residual:  -3.154 |PDE loss  -0.763816
# Total loss: 0.335795 |Boundary loss:  -2.9554 |Initial residual:  -3.1561 |PDE loss  -0.777298
# Total loss: 0.335554 |Boundary loss:  -2.9556 |Initial residual:  -3.1566 |PDE loss  -0.77761
# Total loss: 0.334501 |Boundary loss:  -2.9564 |Initial residual:  -3.1585 |PDE loss  -0.778975
# Total loss: 0.329675 |Boundary loss:  -2.9576 |Initial residual:  -3.1689 |PDE loss  -0.785295
# Total loss: 0.329396 |Boundary loss:  -2.9578 |Initial residual:  -3.1696 |PDE loss  -0.785663
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[42], line 14
#      11 init_kaiming(net.model)
#      12 # torch compile the model
#      13 #net.model = torch.compile(net.model)
# ---> 14 net.train(diff, 100, training_set=training_set)
#
# Cell In[9], line 62, in Net.train(self, diff, epochs, training_set, verbose, freq)
#      59             train_losses[2] = loss_pde
#      60             return loss_f
# ---> 62         self.optimizer.step(closure=closure)
#      63 return train_losses
#
# File c:\Users\ivt\Anaconda3\lib\site-packages\torch\optim\optimizer.py:140, in Optimizer._hook_for_profile.<locals>.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     138 profile_name = "Optimizer.step#{}.step".format(obj.__class__.__name__)
#     139 with torch.autograd.profiler.record_function(profile_name):
# --> 140     out = func(*args, **kwargs)
#     141     obj._optimizer_step_code()
#     142     return out
#
# File c:\Users\ivt\Anaconda3\lib\site-packages\torch\autograd\grad_mode.py:27, in _DecoratorContextManager.__call__.<locals>.decorate_context(*args, **kwargs)
#      24 @functools.wraps(func)
#      25 def decorate_context(*args, **kwargs):
#      26     with self.clone():
# ---> 27         return func(*args, **kwargs)
#
# File c:\Users\ivt\Anaconda3\lib\site-packages\torch\optim\lbfgs.py:426, in LBFGS.step(self, closure)
#     423     def obj_func(x, t, d):
#     424         return self._directional_evaluate(closure, x, t, d)
# --> 426     loss, flat_grad, t, ls_func_evals = _strong_wolfe(
#     427         obj_func, x_init, t, d, loss, flat_grad, gtd)
#     428 self._add_grad(t, d)
#     429 opt_cond = flat_grad.abs().max() <= tolerance_grad
#
# File c:\Users\ivt\Anaconda3\lib\site-packages\torch\optim\lbfgs.py:99, in _strong_wolfe(obj_func, x, t, d, f, g, gtd, c1, c2, tolerance_change, max_ls)
#      97 g_prev = g_new.clone(memory_format=torch.contiguous_format)
#      98 gtd_prev = gtd_new
# ---> 99 f_new, g_new = obj_func(x, t, d)
#     100 ls_func_evals += 1
#     101 gtd_new = g_new.dot(d)
#
# File c:\Users\ivt\Anaconda3\lib\site-packages\torch\optim\lbfgs.py:424, in LBFGS.step.<locals>.obj_func(x, t, d)
#     423 def obj_func(x, t, d):
# --> 424     return self._directional_evaluate(closure, x, t, d)
#
# File c:\Users\ivt\Anaconda3\lib\site-packages\torch\optim\lbfgs.py:278, in LBFGS._directional_evaluate(self, closure, x, t, d)
#     276 def _directional_evaluate(self, closure, x, t, d):
#     277     self._add_grad(t, d)
# --> 278     loss = float(closure())
#     279     flat_grad = self._gather_flat_grad()
#     280     self._set_param(x)
#
# File c:\Users\ivt\Anaconda3\lib\site-packages\torch\autograd\grad_mode.py:27, in _DecoratorContextManager.__call__.<locals>.decorate_context(*args, **kwargs)
#      24 @functools.wraps(func)
#      25 def decorate_context(*args, **kwargs):
#      26     with self.clone():
# ---> 27         return func(*args, **kwargs)
#
# Cell In[9], line 55, in Net.train.<locals>.closure()
#      53 def closure():
#      54     self.optimizer.zero_grad()
# ---> 55     loss_f, loss_vars, loss_pde = CustomLoss().forward(diff, self.model, x_u_train, u_train, x_b_train, u_b_train, x_coll_train, training_set)
#      56     loss_f.backward()
#      57     train_losses[0] = loss_f
#
# Cell In[41], line 29, in CustomLoss.forward(self, diff, net, x_u_train, u_train, x_b_train, u_b_train, x_f_train, dataclass)
#      26 u_pred_ini_vars = torch.cat(u_pred_ini_list,0)
#      27 u_train_ini_vars = torch.cat(u_train_ini_list,0)
# ---> 29 assert not torch.isnan(u_pred_bound_vars).any()
#      30 assert not torch.isnan(u_train_bound_vars).any()
#      32 loss_bound = torch.mean(abs(u_pred_bound_vars - u_train_bound_vars)**2)
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt
boundary = training_set.data_boundary
x_boundary, u_boundary = next(iter(boundary))
print(x_boundary.shape)
print(u_boundary.shape)
plt.plot(x_boundary[:,1].numpy(), x_boundary[:,2].numpy(), 'ro')
plt.show()
plt.plot(x_boundary[:,1].numpy(), u_boundary.view(-1,).numpy(), 'go')
#plt.plot(boundary[:,1].numpy(), boundary[0][:,2].numpy(), 'ro')
#plt.plot(boundary[1].numpy(), boundary[1].numpy(), 'go')


# initial points
initial_points = training_set.data_initial_internal
initial_points = next(iter(initial_points))
print(len(initial_points))
print(initial_points[0].shape)
print(type(initial_points[0]))
plt.plot(initial_points[0][:,1].numpy(), initial_points[0][:,2].numpy(), 'bo')
plt.show()

# collocation points
coll_points = training_set.data_coll
coll_points = next(iter(coll_points))
print(len(coll_points))
print(coll_points[0].shape)
print(type(coll_points[0]))
plt.plot(coll_points[0][:,1].numpy(), coll_points[0][:,2].numpy(), 'go')
plt.show()
# Out:
# torch.Size([2048, 3])
# torch.Size([2048, 1, 1])
# 2
# torch.Size([1024, 3])
# <class 'torch.Tensor'>
# 2
# torch.Size([1024, 3])
# <class 'torch.Tensor'>

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D  # This import registers the 3D projection, but is otherwise unused.

# Assuming 'boundary' is already defined as shown in your code snippet

# Extract x, y, and z coordinates
x_boundary, u_boundary = diff.add_boundary_points(10, 32)
x = x_boundary[:,1]
y = x_boundary[:,2]
#tn = x_boundary[:,0]
z = u_boundary.numpy()
print(x_boundary[:,1:3].shape)
z = diff.ub0(x_boundary)[0].detach().numpy()

# Create a new figure for the 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot using scatter
ax.scatter(x, y, z, c='r', marker='o')

# Set labels for axes
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

# Show the plot
plt.show()
# Out:
# sobol
# sobol
# sobol
# sobol
# boundary_values: torch.Size([40, 1, 1])
# torch.Size([40, 2])

# %%
diff.add_boundary_points(32)
device = "cuda:0"
boundary[0] = boundary[0].to(device)
boundary[1] = boundary[1].to(device)


diff.apply_bc(net.model, boundary[0], boundary[1],[], [])
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D  # This import registers the 3D projection, but is otherwise unused.

# Assuming 'boundary' is already defined as shown in your code snippet

# Extract x, y, and z coordinates
x = boundary[0][:,1].cpu().numpy()
y = boundary[0][:,2].cpu().numpy()
z = boundary[1].cpu().numpy()

# Create a new figure for the 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot using scatter
ax.scatter(x, y, z, c='r', marker='o')

# Set labels for axes
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

# Show the plot
plt.show()
# Out:
# sobol
# sobol
# sobol
# sobol
# boundary_values: torch.Size([128, 1, 1])
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 3
#       1 diff.add_boundary_points(32)
#       2 device = "cuda:0"
# ----> 3 boundary[0] = boundary[0].to(device)
#       4 boundary[1] = boundary[1].to(device)
#       7 diff.apply_bc(net.model, boundary[0], boundary[1],[], [])
#
# TypeError: 'DataLoader' object is not subscriptable

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter


fig = plt.figure()
ax = plt.axes(projection='3d')

x = np.arange(0,1,0.02)
y = np.arange(0,1,.02)
xm, ym = np.meshgrid(x,y)

x = np.ravel(xm).reshape(-1,1)
y = np.ravel(ym).reshape(-1,1)

x_input = Variable(torch.from_numpy(x).float(), requires_grad=True).to(device)
y_input = Variable(torch.from_numpy(y).float(), requires_grad=True).to(device)
t_input = Variable(torch.ones_like(x_input)*2.2, requires_grad=True).to(device)
X = torch.cat([t_input, x_input,y_input],1)

u_pred = net.model(X)
um = u_pred.data.cpu().numpy()
um = um.reshape(xm.shape)

surf = ax.plot_surface(xm, ym, um, cmap=cm.coolwarm, linewidth=0, antialiased=False)

ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))

fig.colorbar(surf, shrink=.5, aspect=5)
plt.show()

# %%
def solution(x,y,t):
    return np.exp(x + y) * np.cos(x + y + 4*t)
anal_sol = solution(x,y,0.01)
mse=np.mean((anal_sol-u_pred.data.cpu().numpy())**2)

# %%
mse
# Out:
# 1.5583141393427689

# %% [markdown]
# ## Analytical solution to heat equation

# %%
fig2 = plt.figure()
ax2 = plt.axes(projection='3d')

xm = np.arange(0,2,0.02)
ym = np.arange(0,2,.02)
xm, ym = np.meshgrid(xm,ym)
anal_sol = solution(xm,ym,0.01)

surf = ax2.plot_surface(xm, ym, anal_sol, cmap=cm.coolwarm, linewidth=0, antialiased=False)
ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))
fig2.colorbar(surf, shrink=.5, aspect=5)
plt.show()
